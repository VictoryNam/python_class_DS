# %% [markdown]
# Task 1

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
x = [1, 2, 3, 4, 5, 6, 7]
y = [3.5, 3.8, 4.2, 4.5, 5, 5.5, 7]
plt.plot(x, y)
plt.show()

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# Task 2

# %%
t = np.linspace(1, 10, num = 51, endpoint=True)

# %%
f = np.sin(t)

# %%
# %config InlineBackend.figure_format = 'svg'

# %%
plt.plot(t,f, color="green")
#доделать оформление
plt.title("График функции f(t)")
plt.xlabel("Значения t")
plt.ylabel("Значения f")
plt.axis([0.5, 9.5, -2.5, 2.5])
# Out:
# (0.5, 9.5, -2.5, 2.5)

# %% [markdown]
# Task 3

# %%
x = np.linspace(-3, 3, num = 51, endpoint = True)

# %%
y1 = x**2
y2 = 2*x + 0.5
y3 = -3*x - 1.5
y4 = np.sin(x)

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
ax1, ax2, ax3, ax4 = ax.flatten()

fig.set_size_inches(8, 6)
fig.subplots_adjust(wspace=0.3, hspace=0.3)

ax1.plot(x, y1, color="red")
ax1.set_title("График y1")
ax1.set_xlim([-5, 5])

ax2.plot(x, y2, color="orange")
ax2.set_title("График y2")

ax3.plot(x, y3, color="yellow")
ax3.set_title("График y3")

ax4.plot(x, y4, color="green")
ax4.set_title("График y4")
# Out:
# Text(0.5, 1.0, 'График y4')

# %% [markdown]
# Task 4

# %%
import pandas as pd

# %%
DATASET_PATH = './Desktop/lib python/creditcard.csv'
PREPARED_DATASET_PATH = './Desktop/lib python/creditcard.csv'

# %%
df = pd.read_csv(DATASET_PATH, sep=',')
df.head(4)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.125895 -0.008983  0.014724    2.69      0
# ...

# %%
plt.style.use('fivethirtyeight')

# %%
value_counts_class = df['Class'].value_counts()

# %%
value_counts_class.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
 value_counts_class.plot(kind="bar", logy=True)
# Out:
# <AxesSubplot:>

# %%
v1 = df.loc[["Class"==1], "V1"].tolist()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-69-895492c56ed4> in <module>
# ----> 1 v1 = df.loc[["Class"==1], "V1"].tolist()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1058     def _getitem_tuple(self, tup: Tuple):
#    1059         with suppress(IndexingError):
# -> 1060             return self._getitem_lowerdim(tup)
#    1061
#    1062         # no multi-index, so validate all of the indexers
#
# ...

# %%
plt.hist(v1)
# Out:
# (array([1.00000e+00, 1.00000e+00, 3.00000e+00, 1.80000e+01, 3.00000e+01,
#         8.10000e+01, 1.84000e+02, 8.89000e+02, 9.46200e+03, 2.74138e+05]),
#  array([-56.40750963, -50.52126567, -44.63502171, -38.74877774,
#         -32.86253378, -26.97628982, -21.09004586, -15.2038019 ,
#          -9.31755793,  -3.43131397,   2.45492999]),
#  <BarContainer object of 10 artists>)
